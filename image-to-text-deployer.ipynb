# %%
# !pip install torch
from sagemaker.pytorch import PyTorch as torch
from sagemaker.huggingface import HuggingFaceModel
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting torch
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch)
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch)
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch)
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch)
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch)
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch)
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch)
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting triton==2.0.0 (from torch)
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Collecting cmake (from triton==2.0.0->torch)
#   Using cached cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
# Collecting lit (from triton==2.0.0->torch)
#   Using cached lit-16.0.6.tar.gz (153 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=0f03152580e380ddec4c748ca756e04d9e00ef081dd7995b78a3f57f4d0a7506
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/14/f9/07/bb2308587bc2f57158f905a2325f6a89a2befa7437b2d7e137
# Successfully built lit
# Installing collected packages: lit, cmake, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch
# Successfully installed cmake-3.26.4 lit-16.0.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 triton-2.0.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 24.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 45.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (1.22.3)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (2023.5.5)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (2.29.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 43.8 MB/s eta 0:00:0000:0100:01m
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 96.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->transformers) (2023.5.7)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2

# %%
# For notebook instances (Amazon Linux)
# !sudo yum update -y 
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.rpm.sh | sudo bash
# !sudo yum install git-lfs git -y


# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.rpm.sh | sudo bash
# !sudo yum-config-manager --add-repo https://packagecloud.io/github/git-lfs/el/7/x86_64
# !sudo yum install -y git-lfs --nogpgcheck
# Out:
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/2): libnvidia-container/x86_64/primary                  |  30 kB   00:00
# (2/2): neuron/primary_db                                   | 133 kB   00:00
# libnvidia-container                                                     190/190
# 61 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package cloud-init.noarch 0:19.3-46.amzn2 will be updated
# ---> Package cloud-init.noarch 0:19.3-46.amzn2.0.1 will be an update
# ---> Package curl.x86_64 0:7.88.1-1.amzn2.0.1 will be updated
# ---> Package curl.x86_64 0:8.0.1-1.amzn2.0.1 will be an update
# ---> Package dnsmasq.x86_64 0:2.76-16.amzn2.1.3 will be updated
# ---> Package dnsmasq.x86_64 0:2.76-16.amzn2.1.4 will be an update
# ---> Package fuse-overlayfs.x86_64 0:0.7.2-6.amzn2int will be updated
# ---> Package fuse-overlayfs.x86_64 0:0.7.2-6.el7_8 will be an update
# ---> Package git.x86_64 0:2.39.2-1.amzn2.0.1 will be updated
# ---> Package git.x86_64 0:2.40.1-1.amzn2.0.1 will be an update
# ---> Package git-core.x86_64 0:2.39.2-1.amzn2.0.1 will be updated
# ---> Package git-core.x86_64 0:2.40.1-1.amzn2.0.1 will be an update
# ---> Package git-core-doc.noarch 0:2.39.2-1.amzn2.0.1 will be updated
# ---> Package git-core-doc.noarch 0:2.40.1-1.amzn2.0.1 will be an update
# ---> Package grub2.x86_64 1:2.06-9.amzn2.0.1 will be obsoleted
# ---> Package grub2.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package grub2-common.noarch 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-common.noarch 1:2.06-9.amzn2.0.3 will be an update
# ---> Package grub2-efi-x64-ec2.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-efi-x64-ec2.x86_64 1:2.06-9.amzn2.0.3 will be an update
# ---> Package grub2-pc.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-pc.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package grub2-pc-modules.noarch 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-pc-modules.noarch 1:2.06-9.amzn2.0.3 will be an update
# ---> Package grub2-tools.x86_64 1:2.06-9.amzn2.0.1 will be obsoleted
# ---> Package grub2-tools.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package grub2-tools-efi.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package grub2-tools-extra.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package grub2-tools-minimal.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-tools-minimal.x86_64 1:2.06-9.amzn2.0.3 will be obsoleting
# ---> Package gstreamer1.x86_64 0:1.10.4-2.amzn2.0.2 will be updated
# ---> Package gstreamer1.x86_64 0:1.18.4-4.amzn2.0.1 will be an update
# ---> Package gstreamer1-plugins-bad-free.x86_64 0:1.10.4-3.amzn2 will be updated
# ---> Package gstreamer1-plugins-bad-free.x86_64 0:1.18.4-5.amzn2.0.1 will be an update
# --> Processing Dependency: libwebrtc_audio_processing.so.1()(64bit) for package: gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: libwebp.so.7()(64bit) for package: gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: libgudev-1.0.so.0()(64bit) for package: gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64
# ---> Package gstreamer1-plugins-base.x86_64 0:1.10.4-2.amzn2.0.3 will be updated
# ---> Package gstreamer1-plugins-base.x86_64 0:1.18.4-5.amzn2.0.1 will be an update
# --> Processing Dependency: libgraphene-1.0.so.0()(64bit) for package: gstreamer1-plugins-base-1.18.4-5.amzn2.0.1.x86_64
# ---> Package hibagent.noarch 0:1.1.0-5.amzn2 will be updated
# ---> Package hibagent.noarch 0:1.1.0-6.amzn2 will be an update
# ---> Package ibacm.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package ibacm.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package infiniband-diags.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package infiniband-diags.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package iso-codes.noarch 0:3.46-2.amzn2 will be updated
# ---> Package iso-codes.noarch 0:4.6.0-3.amzn2 will be an update
# ---> Package kernel-devel.x86_64 0:5.10.179-171.711.amzn2 will be installed
# ---> Package kernel-headers.x86_64 0:5.10.179-168.710.amzn2 will be updated
# ---> Package kernel-headers.x86_64 0:5.10.179-171.711.amzn2 will be an update
# ---> Package kpatch-runtime.noarch 0:0.9.4-7.amzn2 will be updated
# ---> Package kpatch-runtime.noarch 0:0.9.4-8.amzn2 will be an update
# ---> Package libcurl.x86_64 0:7.88.1-1.amzn2.0.1 will be updated
# ---> Package libcurl.x86_64 0:8.0.1-1.amzn2.0.1 will be an update
# ---> Package libcurl-devel.x86_64 0:7.88.1-1.amzn2.0.1 will be updated
# ---> Package libcurl-devel.x86_64 0:8.0.1-1.amzn2.0.1 will be an update
# ---> Package libfastjson.x86_64 0:0.99.4-3.amzn2 will be updated
# ---> Package libfastjson.x86_64 0:0.99.4-3.amzn2.0.1 will be an update
# ---> Package libibumad.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibumad.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs-core.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs-core.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs-utils.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs-utils.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libnvidia-container-tools.x86_64 0:1.13.1-1 will be updated
# ---> Package libnvidia-container-tools.x86_64 0:1.13.2-1 will be an update
# ---> Package libnvidia-container1.x86_64 0:1.13.1-1 will be updated
# ---> Package libnvidia-container1.x86_64 0:1.13.2-1 will be an update
# ---> Package librdmacm.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package librdmacm.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package librdmacm-utils.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package librdmacm-utils.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package nvidia-container-toolkit.x86_64 0:1.13.1-1 will be updated
# ---> Package nvidia-container-toolkit.x86_64 0:1.13.2-1 will be an update
# ---> Package nvidia-container-toolkit-base.x86_64 0:1.13.1-1 will be updated
# ---> Package nvidia-container-toolkit-base.x86_64 0:1.13.2-1 will be an update
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.2 will be an update
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.2 will be an update
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.2 will be an update
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.6 will be updated
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.7 will be an update
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.6 will be updated
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.7 will be an update
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.6 will be updated
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.7 will be an update
# ---> Package pcre.x86_64 0:8.32-17.amzn2.0.2 will be updated
# ---> Package pcre.x86_64 0:8.32-17.amzn2.0.3 will be an update
# ---> Package pcre-devel.x86_64 0:8.32-17.amzn2.0.2 will be updated
# ---> Package pcre-devel.x86_64 0:8.32-17.amzn2.0.3 will be an update
# ---> Package perl-Git.noarch 0:2.39.2-1.amzn2.0.1 will be updated
# ---> Package perl-Git.noarch 0:2.40.1-1.amzn2.0.1 will be an update
# ---> Package python-pillow.x86_64 0:2.0.0-23.gitd1c6db8.amzn2.0.1 will be updated
# ---> Package python-pillow.x86_64 0:2.0.0-23.gitd1c6db8.amzn2.0.5 will be an update
# ---> Package rdma-core.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package rdma-core.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package rdma-core-devel.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package rdma-core-devel.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package rsync.x86_64 0:3.1.2-11.amzn2.0.1 will be updated
# ---> Package rsync.x86_64 0:3.1.2-11.amzn2.0.2 will be an update
# ---> Package runc.x86_64 0:1.1.5-1.amzn2 will be updated
# ---> Package runc.x86_64 0:1.1.7-1.amzn2 will be an update
# ---> Package sysstat.x86_64 0:10.1.5-18.amzn2.0.2 will be updated
# ---> Package sysstat.x86_64 0:10.1.5-18.amzn2.0.3 will be an update
# ---> Package vim-common.x86_64 2:9.0.1403-1.amzn2.0.2 will be updated
# ---> Package vim-common.x86_64 2:9.0.1592-1.amzn2.0.1 will be an update
# --> Processing Dependency: xxd for package: 2:vim-common-9.0.1592-1.amzn2.0.1.x86_64
# ---> Package vim-data.noarch 2:9.0.1403-1.amzn2.0.2 will be updated
# ---> Package vim-data.noarch 2:9.0.1592-1.amzn2.0.1 will be an update
# ---> Package vim-enhanced.x86_64 2:9.0.1403-1.amzn2.0.2 will be updated
# ---> Package vim-enhanced.x86_64 2:9.0.1592-1.amzn2.0.1 will be an update
# ---> Package vim-filesystem.noarch 2:9.0.1403-1.amzn2.0.2 will be updated
# ---> Package vim-filesystem.noarch 2:9.0.1592-1.amzn2.0.1 will be an update
# ---> Package vim-minimal.x86_64 2:9.0.1403-1.amzn2.0.2 will be updated
# ---> Package vim-minimal.x86_64 2:9.0.1592-1.amzn2.0.1 will be an update
# ---> Package webkitgtk4.x86_64 0:2.28.2-3.amzn2.0.2 will be updated
# ---> Package webkitgtk4.x86_64 0:2.38.5-3.amzn2.0.1 will be an update
# ---> Package webkitgtk4-jsc.x86_64 0:2.28.2-3.amzn2.0.2 will be updated
# ---> Package webkitgtk4-jsc.x86_64 0:2.38.5-3.amzn2.0.1 will be an update
# --> Running transaction check
# ---> Package graphene.x86_64 0:1.10.6-2.amzn2.0.2 will be installed
# ---> Package libgudev1.x86_64 0:219-78.amzn2.0.22 will be installed
# ---> Package libwebp12.x86_64 0:1.2.0-3.amzn2.0.1 will be installed
# ---> Package webrtc-audio-processing.x86_64 0:0.3-1.amzn2.0.1 will be installed
# ---> Package xxd.x86_64 2:9.0.1592-1.amzn2.0.1 will be installed
# --> Finished Dependency Resolution
# --> Running transaction check
# ---> Package kernel-devel.x86_64 0:5.10.109-104.500.amzn2 will be erased
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package           Arch   Version                 Repository               Size
# ================================================================================
# Installing:
#  grub2             x86_64 1:2.06-9.amzn2.0.3      amzn2-core               46 k
#      replacing  grub2.x86_64 1:2.06-9.amzn2.0.1
#  grub2-pc          x86_64 1:2.06-9.amzn2.0.3      amzn2-core               45 k
#      replacing  grub2.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools       x86_64 1:2.06-9.amzn2.0.3      amzn2-core              2.0 M
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-efi   x86_64 1:2.06-9.amzn2.0.3      amzn2-core              560 k
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-extra x86_64 1:2.06-9.amzn2.0.3      amzn2-core              1.0 M
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-minimal
#                    x86_64 1:2.06-9.amzn2.0.3      amzn2-core              624 k
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  kernel-devel      x86_64 5.10.179-171.711.amzn2  amzn2extra-kernel-5.10   16 M
# Updating:
#  cloud-init        noarch 19.3-46.amzn2.0.1       amzn2-core              927 k
#  curl              x86_64 8.0.1-1.amzn2.0.1       amzn2-core              400 k
#  dnsmasq           x86_64 2.76-16.amzn2.1.4       amzn2-core              280 k
#  fuse-overlayfs    x86_64 0.7.2-6.el7_8           centos-extras            54 k
#  git               x86_64 2.40.1-1.amzn2.0.1      amzn2-core               54 k
#  git-core          x86_64 2.40.1-1.amzn2.0.1      amzn2-core               10 M
#  git-core-doc      noarch 2.40.1-1.amzn2.0.1      amzn2-core              3.0 M
#  grub2-common      noarch 1:2.06-9.amzn2.0.3      amzn2-core              1.8 M
#  grub2-efi-x64-ec2 x86_64 1:2.06-9.amzn2.0.3      amzn2-core              282 k
#  grub2-pc-modules  noarch 1:2.06-9.amzn2.0.3      amzn2-core              938 k
#  gstreamer1        x86_64 1.18.4-4.amzn2.0.1      amzn2-core              1.3 M
#  gstreamer1-plugins-bad-free
#                    x86_64 1.18.4-5.amzn2.0.1      amzn2-core              2.0 M
#  gstreamer1-plugins-base
#                    x86_64 1.18.4-5.amzn2.0.1      amzn2-core              2.0 M
#  hibagent          noarch 1.1.0-6.amzn2           amzn2-core               18 k
#  ibacm             x86_64 43.0-1.amzn2.0.2        amzn2-core               84 k
#  infiniband-diags  x86_64 43.0-1.amzn2.0.2        amzn2-core              296 k
#  iso-codes         noarch 4.6.0-3.amzn2           amzn2-core              3.7 M
#  kernel-headers    x86_64 5.10.179-171.711.amzn2  amzn2extra-kernel-5.10  1.4 M
#  kpatch-runtime    noarch 0.9.4-8.amzn2           amzn2-core               28 k
#  libcurl           x86_64 8.0.1-1.amzn2.0.1       amzn2-core              346 k
#  libcurl-devel     x86_64 8.0.1-1.amzn2.0.1       amzn2-core              949 k
#  libfastjson       x86_64 0.99.4-3.amzn2.0.1      amzn2-core               27 k
#  libibumad         x86_64 43.0-1.amzn2.0.2        amzn2-core               26 k
#  libibverbs        x86_64 43.0-1.amzn2.0.2        amzn2-core              333 k
#  libibverbs-core   x86_64 43.0-1.amzn2.0.2        amzn2-core               85 k
#  libibverbs-utils  x86_64 43.0-1.amzn2.0.2        amzn2-core               62 k
#  libnvidia-container-tools
#                    x86_64 1.13.2-1                libnvidia-container      51 k
#  libnvidia-container1
#                    x86_64 1.13.2-1                libnvidia-container     1.0 M
#  librdmacm         x86_64 43.0-1.amzn2.0.2        amzn2-core               69 k
#  librdmacm-utils   x86_64 43.0-1.amzn2.0.2        amzn2-core               86 k
#  nvidia-container-toolkit
#                    x86_64 1.13.2-1                libnvidia-container     909 k
#  nvidia-container-toolkit-base
#                    x86_64 1.13.2-1                libnvidia-container     3.1 M
#  openssh           x86_64 7.4p1-22.amzn2.0.2      amzn2-core              507 k
#  openssh-clients   x86_64 7.4p1-22.amzn2.0.2      amzn2-core              650 k
#  openssh-server    x86_64 7.4p1-22.amzn2.0.2      amzn2-core              457 k
#  openssl           x86_64 1:1.0.2k-24.amzn2.0.7   amzn2-core              497 k
#  openssl-devel     x86_64 1:1.0.2k-24.amzn2.0.7   amzn2-core              1.5 M
#  openssl-libs      x86_64 1:1.0.2k-24.amzn2.0.7   amzn2-core              1.2 M
#  pcre              x86_64 8.32-17.amzn2.0.3       amzn2-core              430 k
#  pcre-devel        x86_64 8.32-17.amzn2.0.3       amzn2-core              480 k
#  perl-Git          noarch 2.40.1-1.amzn2.0.1      amzn2-core               41 k
#  python-pillow     x86_64 2.0.0-23.gitd1c6db8.amzn2.0.5
#                                                   amzn2-core              443 k
#  rdma-core         x86_64 43.0-1.amzn2.0.2        amzn2-core               55 k
#  rdma-core-devel   x86_64 43.0-1.amzn2.0.2        amzn2-core              377 k
#  rsync             x86_64 3.1.2-11.amzn2.0.2      amzn2-core              407 k
#  runc              x86_64 1.1.7-1.amzn2           amzn2extra-docker       2.9 M
#  sysstat           x86_64 10.1.5-18.amzn2.0.3     amzn2-core              318 k
#  vim-common        x86_64 2:9.0.1592-1.amzn2.0.1  amzn2-core              7.9 M
#  vim-data          noarch 2:9.0.1592-1.amzn2.0.1  amzn2-core               81 k
#  vim-enhanced      x86_64 2:9.0.1592-1.amzn2.0.1  amzn2-core              1.6 M
#  vim-filesystem    noarch 2:9.0.1592-1.amzn2.0.1  amzn2-core               75 k
#  vim-minimal       x86_64 2:9.0.1592-1.amzn2.0.1  amzn2-core              745 k
#  webkitgtk4        x86_64 2.38.5-3.amzn2.0.1      amzn2-core               34 M
#  webkitgtk4-jsc    x86_64 2.38.5-3.amzn2.0.1      amzn2-core              7.2 M
# Removing:
#  kernel-devel      x86_64 5.10.109-104.500.amzn2  @amzn2extra-kernel-5.10  76 M
# Installing for dependencies:
#  graphene          x86_64 1.10.6-2.amzn2.0.2      amzn2-core               59 k
#  libgudev1         x86_64 219-78.amzn2.0.22       amzn2-core              111 k
#  libwebp12         x86_64 1.2.0-3.amzn2.0.1       amzn2-core              269 k
#  webrtc-audio-processing
#                    x86_64 0.3-1.amzn2.0.1         amzn2-core              282 k
#  xxd               x86_64 2:9.0.1592-1.amzn2.0.1  amzn2-core               90 k
#
# Transaction Summary
# ================================================================================
# Install   7 Packages (+5 Dependent packages)
# Upgrade  54 Packages
# Remove    1 Package
#
# Total download size: 118 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# (1/66): cloud-init-19.3-46.amzn2.0.1.noarch.rpm            | 927 kB   00:00
# (2/66): dnsmasq-2.76-16.amzn2.1.4.x86_64.rpm               | 280 kB   00:00
# (3/66): curl-8.0.1-1.amzn2.0.1.x86_64.rpm                  | 400 kB   00:00
# (4/66): git-2.40.1-1.amzn2.0.1.x86_64.rpm                  |  54 kB   00:00
# (5/66): git-core-doc-2.40.1-1.amzn2.0.1.noarch.rpm         | 3.0 MB   00:00
# (6/66): graphene-1.10.6-2.amzn2.0.2.x86_64.rpm             |  59 kB   00:00
# (7/66): grub2-2.06-9.amzn2.0.3.x86_64.rpm                  |  46 kB   00:00
# (8/66): git-core-2.40.1-1.amzn2.0.1.x86_64.rpm             |  10 MB   00:00
# (9/66): grub2-common-2.06-9.amzn2.0.3.noarch.rpm           | 1.8 MB   00:00
# (10/66): grub2-efi-x64-ec2-2.06-9.amzn2.0.3.x86_64.rpm     | 282 kB   00:00
# (11/66): grub2-pc-modules-2.06-9.amzn2.0.3.noarch.rpm      | 938 kB   00:00
# (12/66): grub2-pc-2.06-9.amzn2.0.3.x86_64.rpm              |  45 kB   00:00
# (13/66): grub2-tools-2.06-9.amzn2.0.3.x86_64.rpm           | 2.0 MB   00:00
# (14/66): grub2-tools-efi-2.06-9.amzn2.0.3.x86_64.rpm       | 560 kB   00:00
# (15/66): grub2-tools-extra-2.06-9.amzn2.0.3.x86_64.rpm     | 1.0 MB   00:00
# (16/66): grub2-tools-minimal-2.06-9.amzn2.0.3.x86_64.rpm   | 624 kB   00:00
# (17/66): gstreamer1-1.18.4-4.amzn2.0.1.x86_64.rpm          | 1.3 MB   00:00
# (18/66): gstreamer1-plugins-base-1.18.4-5.amzn2.0.1.x86_64 | 2.0 MB   00:00
# (19/66): gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x8 | 2.0 MB   00:00
# (20/66): hibagent-1.1.0-6.amzn2.noarch.rpm                 |  18 kB   00:00
# (21/66): infiniband-diags-43.0-1.amzn2.0.2.x86_64.rpm      | 296 kB   00:00
# (22/66): ibacm-43.0-1.amzn2.0.2.x86_64.rpm                 |  84 kB   00:00
# (23/66): iso-codes-4.6.0-3.amzn2.noarch.rpm                | 3.7 MB   00:00
# (24/66): kpatch-runtime-0.9.4-8.amzn2.noarch.rpm           |  28 kB   00:00
# (25/66): fuse-overlayfs-0.7.2-6.el7_8.x86_64.rpm           |  54 kB   00:00
# (26/66): libcurl-8.0.1-1.amzn2.0.1.x86_64.rpm              | 346 kB   00:00
# (27/66): libcurl-devel-8.0.1-1.amzn2.0.1.x86_64.rpm        | 949 kB   00:00
# (28/66): libfastjson-0.99.4-3.amzn2.0.1.x86_64.rpm         |  27 kB   00:00
# (29/66): libgudev1-219-78.amzn2.0.22.x86_64.rpm            | 111 kB   00:00
# (30/66): libibumad-43.0-1.amzn2.0.2.x86_64.rpm             |  26 kB   00:00
# (31/66): libibverbs-core-43.0-1.amzn2.0.2.x86_64.rpm       |  85 kB   00:00
# (32/66): kernel-headers-5.10.179-171.711.amzn2.x86_64.rpm  | 1.4 MB   00:00
# (33/66): libibverbs-43.0-1.amzn2.0.2.x86_64.rpm            | 333 kB   00:00
# (34/66): libibverbs-utils-43.0-1.amzn2.0.2.x86_64.rpm      |  62 kB   00:00
# (35/66): kernel-devel-5.10.179-171.711.amzn2.x86_64.rpm    |  16 MB   00:00
# (36/66): librdmacm-43.0-1.amzn2.0.2.x86_64.rpm             |  69 kB   00:00
# (37/66): libnvidia-container-tools-1.13.2-1.x86_64.rpm     |  51 kB   00:00
# (38/66): libnvidia-container1-1.13.2-1.x86_64.rpm          | 1.0 MB   00:00
# (39/66): libwebp12-1.2.0-3.amzn2.0.1.x86_64.rpm            | 269 kB   00:00
# (40/66): nvidia-container-toolkit-1.13.2-1.x86_64.rpm      | 909 kB   00:00
# (41/66): openssh-7.4p1-22.amzn2.0.2.x86_64.rpm             | 507 kB   00:00
# (42/66): librdmacm-utils-43.0-1.amzn2.0.2.x86_64.rpm       |  86 kB   00:00
# (43/66): openssh-clients-7.4p1-22.amzn2.0.2.x86_64.rpm     | 650 kB   00:00
# (44/66): openssh-server-7.4p1-22.amzn2.0.2.x86_64.rpm      | 457 kB   00:00
# (45/66): openssl-1.0.2k-24.amzn2.0.7.x86_64.rpm            | 497 kB   00:00
# (46/66): openssl-devel-1.0.2k-24.amzn2.0.7.x86_64.rpm      | 1.5 MB   00:00
# (47/66): pcre-8.32-17.amzn2.0.3.x86_64.rpm                 | 430 kB   00:00
# (48/66): openssl-libs-1.0.2k-24.amzn2.0.7.x86_64.rpm       | 1.2 MB   00:00
# (49/66): pcre-devel-8.32-17.amzn2.0.3.x86_64.rpm           | 480 kB   00:00
# (50/66): perl-Git-2.40.1-1.amzn2.0.1.noarch.rpm            |  41 kB   00:00
# (51/66): python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.5.x86_6 | 443 kB   00:00
# (52/66): rdma-core-43.0-1.amzn2.0.2.x86_64.rpm             |  55 kB   00:00
# (53/66): nvidia-container-toolkit-base-1.13.2-1.x86_64.rpm | 3.1 MB   00:00
# (54/66): rsync-3.1.2-11.amzn2.0.2.x86_64.rpm               | 407 kB   00:00
# (55/66): rdma-core-devel-43.0-1.amzn2.0.2.x86_64.rpm       | 377 kB   00:00
# (56/66): sysstat-10.1.5-18.amzn2.0.3.x86_64.rpm            | 318 kB   00:00
# (57/66): vim-data-9.0.1592-1.amzn2.0.1.noarch.rpm          |  81 kB   00:00
# (58/66): vim-enhanced-9.0.1592-1.amzn2.0.1.x86_64.rpm      | 1.6 MB   00:00
# (59/66): vim-common-9.0.1592-1.amzn2.0.1.x86_64.rpm        | 7.9 MB   00:00
# (60/66): vim-filesystem-9.0.1592-1.amzn2.0.1.noarch.rpm    |  75 kB   00:00
# (61/66): runc-1.1.7-1.amzn2.x86_64.rpm                     | 2.9 MB   00:00
# (62/66): vim-minimal-9.0.1592-1.amzn2.0.1.x86_64.rpm       | 745 kB   00:00
# (63/66): webkitgtk4-jsc-2.38.5-3.amzn2.0.1.x86_64.rpm      | 7.2 MB   00:00
# (64/66): webrtc-audio-processing-0.3-1.amzn2.0.1.x86_64.rp | 282 kB   00:00
# (65/66): xxd-9.0.1592-1.amzn2.0.1.x86_64.rpm               |  90 kB   00:00
# (66/66): webkitgtk4-2.38.5-3.amzn2.0.1.x86_64.rpm          |  34 MB   00:00
# --------------------------------------------------------------------------------
# Total                                               51 MB/s | 118 MB  00:02
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Updating   : 1:openssl-libs-1.0.2k-24.amzn2.0.7.x86_64                  1/125
#   Updating   : 1:grub2-common-2.06-9.amzn2.0.3.noarch                     2/125
#   Updating   : libibverbs-core-43.0-1.amzn2.0.2.x86_64                    3/125
#   Installing : 1:grub2-tools-minimal-2.06-9.amzn2.0.3.x86_64              4/125
#   Updating   : libcurl-8.0.1-1.amzn2.0.1.x86_64                           5/125
#   Updating   : gstreamer1-1.18.4-4.amzn2.0.1.x86_64                       6/125
#   Updating   : libibumad-43.0-1.amzn2.0.2.x86_64                          7/125
#   Updating   : librdmacm-43.0-1.amzn2.0.2.x86_64                          8/125
#   Updating   : libibverbs-43.0-1.amzn2.0.2.x86_64                         9/125
#   Installing : 1:grub2-tools-2.06-9.amzn2.0.3.x86_64                     10/125
#   Updating   : openssh-7.4p1-22.amzn2.0.2.x86_64                         11/125
#   Updating   : 2:vim-data-9.0.1592-1.amzn2.0.1.noarch                    12/125
#   Installing : libwebp12-1.2.0-3.amzn2.0.1.x86_64                        13/125
#   Updating   : openssh-clients-7.4p1-22.amzn2.0.2.x86_64                 14/125
#   Updating   : git-core-2.40.1-1.amzn2.0.1.x86_64                        15/125
#   Updating   : git-core-doc-2.40.1-1.amzn2.0.1.noarch                    16/125
#   Updating   : perl-Git-2.40.1-1.amzn2.0.1.noarch                        17/125
#   Updating   : git-2.40.1-1.amzn2.0.1.x86_64                             18/125
#   Updating   : infiniband-diags-43.0-1.amzn2.0.2.x86_64                  19/125
#   Updating   : 1:grub2-pc-modules-2.06-9.amzn2.0.3.noarch                20/125
#   Installing : 1:grub2-pc-2.06-9.amzn2.0.3.x86_64                        21/125
#   Updating   : iso-codes-4.6.0-3.amzn2.noarch                            22/125
#   Installing : graphene-1.10.6-2.amzn2.0.2.x86_64                        23/125
#   Updating   : gstreamer1-plugins-base-1.18.4-5.amzn2.0.1.x86_64         24/125
#   Updating   : webkitgtk4-jsc-2.38.5-3.amzn2.0.1.x86_64                  25/125
#   Updating   : webkitgtk4-2.38.5-3.amzn2.0.1.x86_64                      26/125
#   Installing : libgudev1-219-78.amzn2.0.22.x86_64                        27/125
#   Updating   : pcre-8.32-17.amzn2.0.3.x86_64                             28/125
#   Updating   : libnvidia-container1-1.13.2-1.x86_64                      29/125
#   Updating   : libnvidia-container-tools-1.13.2-1.x86_64                 30/125
#   Installing : 2:xxd-9.0.1592-1.amzn2.0.1.x86_64                         31/125
#   Installing : webrtc-audio-processing-0.3-1.amzn2.0.1.x86_64            32/125
#   Updating   : 2:vim-filesystem-9.0.1592-1.amzn2.0.1.noarch              33/125
#   Updating   : 2:vim-common-9.0.1592-1.amzn2.0.1.x86_64                  34/125
#   Updating   : nvidia-container-toolkit-base-1.13.2-1.x86_64             35/125
#   Updating   : nvidia-container-toolkit-1.13.2-1.x86_64                  36/125
#   Updating   : 2:vim-enhanced-9.0.1592-1.amzn2.0.1.x86_64                37/125
#   Updating   : gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64     38/125
#   Updating   : pcre-devel-8.32-17.amzn2.0.3.x86_64                       39/125
#   Installing : 1:grub2-2.06-9.amzn2.0.3.x86_64                           40/125
#   Updating   : rdma-core-devel-43.0-1.amzn2.0.2.x86_64                   41/125
#   Updating   : 2:vim-minimal-9.0.1592-1.amzn2.0.1.x86_64                 42/125
#   Updating   : openssh-server-7.4p1-22.amzn2.0.2.x86_64                  43/125
#   Updating   : 1:grub2-efi-x64-ec2-2.06-9.amzn2.0.3.x86_64               44/125
#   Updating   : libibverbs-utils-43.0-1.amzn2.0.2.x86_64                  45/125
#   Updating   : librdmacm-utils-43.0-1.amzn2.0.2.x86_64                   46/125
#   Updating   : ibacm-43.0-1.amzn2.0.2.x86_64                             47/125
#   Updating   : curl-8.0.1-1.amzn2.0.1.x86_64                             48/125
#   Updating   : libcurl-devel-8.0.1-1.amzn2.0.1.x86_64                    49/125
#   Installing : 1:grub2-tools-extra-2.06-9.amzn2.0.3.x86_64               50/125
#   Installing : 1:grub2-tools-efi-2.06-9.amzn2.0.3.x86_64                 51/125
#   Updating   : 1:openssl-devel-1.0.2k-24.amzn2.0.7.x86_64                52/125
#   Updating   : 1:openssl-1.0.2k-24.amzn2.0.7.x86_64                      53/125
#   Updating   : sysstat-10.1.5-18.amzn2.0.3.x86_64                        54/125
#   Updating   : cloud-init-19.3-46.amzn2.0.1.noarch                       55/125
#   Updating   : dnsmasq-2.76-16.amzn2.1.4.x86_64                          56/125
#   Installing : kernel-devel-5.10.179-171.711.amzn2.x86_64                57/125
#   Updating   : rdma-core-43.0-1.amzn2.0.2.x86_64                         58/125
#   Updating   : libfastjson-0.99.4-3.amzn2.0.1.x86_64                     59/125
#   Updating   : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.5.x86_64        60/125
#   Updating   : fuse-overlayfs-0.7.2-6.el7_8.x86_64                       61/125
#   Updating   : kpatch-runtime-0.9.4-8.amzn2.noarch                       62/125
#   Updating   : rsync-3.1.2-11.amzn2.0.2.x86_64                           63/125
#   Updating   : runc-1.1.7-1.amzn2.x86_64                                 64/125
#   Updating   : kernel-headers-5.10.179-171.711.amzn2.x86_64              65/125
#   Updating   : hibagent-1.1.0-6.amzn2.noarch                             66/125
#   Cleanup    : rdma-core-devel-41.0-2.amzn2.0.2.x86_64                   67/125
#   Cleanup    : perl-Git-2.39.2-1.amzn2.0.1.noarch                        68/125
#   Cleanup    : git-2.39.2-1.amzn2.0.1.x86_64                             69/125
#   Cleanup    : 1:grub2-efi-x64-ec2-2.06-9.amzn2.0.1.x86_64               70/125
#   Cleanup    : git-core-doc-2.39.2-1.amzn2.0.1.noarch                    71/125
#   Cleanup    : libcurl-devel-7.88.1-1.amzn2.0.1.x86_64                   72/125
#   Cleanup    : 1:openssl-devel-1.0.2k-24.amzn2.0.6.x86_64                73/125
#   Cleanup    : 1:grub2-2.06-9.amzn2.0.1.x86_64                           74/125
#   Cleanup    : 1:grub2-pc-2.06-9.amzn2.0.1.x86_64                        75/125
#   Cleanup    : 1:grub2-pc-modules-2.06-9.amzn2.0.1.noarch                76/125
#   Cleanup    : pcre-devel-8.32-17.amzn2.0.2.x86_64                       77/125
#   Cleanup    : cloud-init-19.3-46.amzn2.noarch                           78/125
#   Cleanup    : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.1.x86_64        79/125
#   Cleanup    : kernel-devel-5.10.109-104.500.amzn2.x86_64                80/125
#   Cleanup    : kpatch-runtime-0.9.4-7.amzn2.noarch                       81/125
#   Cleanup    : kernel-headers-5.10.179-168.710.amzn2.x86_64              82/125
#   Cleanup    : hibagent-1.1.0-5.amzn2.noarch                             83/125
#   Cleanup    : git-core-2.39.2-1.amzn2.0.1.x86_64                        84/125
#   Cleanup    : curl-7.88.1-1.amzn2.0.1.x86_64                            85/125
#   Cleanup    : openssh-clients-7.4p1-22.amzn2.0.1.x86_64                 86/125
#   Cleanup    : ibacm-41.0-2.amzn2.0.2.x86_64                             87/125
#   Cleanup    : librdmacm-utils-41.0-2.amzn2.0.2.x86_64                   88/125
#   Cleanup    : libibverbs-utils-41.0-2.amzn2.0.2.x86_64                  89/125
#   Cleanup    : openssh-server-7.4p1-22.amzn2.0.1.x86_64                  90/125
#   Cleanup    : nvidia-container-toolkit-1.13.1-1.x86_64                  91/125
#   Cleanup    : libnvidia-container-tools-1.13.1-1.x86_64                 92/125
#   Cleanup    : openssh-7.4p1-22.amzn2.0.1.x86_64                         93/125
#   Cleanup    : libibverbs-41.0-2.amzn2.0.2.x86_64                        94/125
#   Cleanup    : librdmacm-41.0-2.amzn2.0.2.x86_64                         95/125
#   Cleanup    : libcurl-7.88.1-1.amzn2.0.1.x86_64                         96/125
#   Cleanup    : 1:grub2-tools-minimal-2.06-9.amzn2.0.1.x86_64             97/125
#   Cleanup    : 1:grub2-tools-2.06-9.amzn2.0.1.x86_64                     98/125
#   Cleanup    : infiniband-diags-41.0-2.amzn2.0.2.x86_64                  99/125
#   Cleanup    : webkitgtk4-2.28.2-3.amzn2.0.2.x86_64                     100/125
#   Cleanup    : webkitgtk4-jsc-2.28.2-3.amzn2.0.2.x86_64                 101/125
#   Cleanup    : gstreamer1-plugins-bad-free-1.10.4-3.amzn2.x86_64        102/125
#   Cleanup    : gstreamer1-plugins-base-1.10.4-2.amzn2.0.3.x86_64        103/125
#   Cleanup    : 2:vim-enhanced-9.0.1403-1.amzn2.0.2.x86_64               104/125
#   Cleanup    : 2:vim-common-9.0.1403-1.amzn2.0.2.x86_64                 105/125
#   Cleanup    : 1:openssl-1.0.2k-24.amzn2.0.6.x86_64                     106/125
#   Cleanup    : 2:vim-minimal-9.0.1403-1.amzn2.0.2.x86_64                107/125
#   Cleanup    : 2:vim-data-9.0.1403-1.amzn2.0.2.noarch                   108/125
#   Cleanup    : 2:vim-filesystem-9.0.1403-1.amzn2.0.2.noarch             109/125
#   Cleanup    : iso-codes-3.46-2.amzn2.noarch                            110/125
#   Cleanup    : 1:grub2-common-2.06-9.amzn2.0.1.noarch                   111/125
#   Cleanup    : 1:openssl-libs-1.0.2k-24.amzn2.0.6.x86_64                112/125
#   Cleanup    : gstreamer1-1.10.4-2.amzn2.0.2.x86_64                     113/125
#   Cleanup    : libibumad-41.0-2.amzn2.0.2.x86_64                        114/125
#   Cleanup    : libibverbs-core-41.0-2.amzn2.0.2.x86_64                  115/125
#   Cleanup    : libnvidia-container1-1.13.1-1.x86_64                     116/125
#   Cleanup    : nvidia-container-toolkit-base-1.13.1-1.x86_64            117/125
#   Cleanup    : pcre-8.32-17.amzn2.0.2.x86_64                            118/125
#   Cleanup    : sysstat-10.1.5-18.amzn2.0.2.x86_64                       119/125
#   Cleanup    : dnsmasq-2.76-16.amzn2.1.3.x86_64                         120/125
#   Cleanup    : rdma-core-41.0-2.amzn2.0.2.x86_64                        121/125
#   Cleanup    : libfastjson-0.99.4-3.amzn2.x86_64                        122/125
#   Cleanup    : fuse-overlayfs-0.7.2-6.amzn2int.x86_64                   123/125
#   Cleanup    : rsync-3.1.2-11.amzn2.0.1.x86_64                          124/125
#   Cleanup    : runc-1.1.5-1.amzn2.x86_64                                125/125
#   Verifying  : git-core-2.40.1-1.amzn2.0.1.x86_64                         1/125
#   Verifying  : hibagent-1.1.0-6.amzn2.noarch                              2/125
#   Verifying  : git-2.40.1-1.amzn2.0.1.x86_64                              3/125
#   Verifying  : nvidia-container-toolkit-base-1.13.2-1.x86_64              4/125
#   Verifying  : 1:grub2-tools-2.06-9.amzn2.0.3.x86_64                      5/125
#   Verifying  : curl-8.0.1-1.amzn2.0.1.x86_64                              6/125
#   Verifying  : libwebp12-1.2.0-3.amzn2.0.1.x86_64                         7/125
#   Verifying  : libibumad-43.0-1.amzn2.0.2.x86_64                          8/125
#   Verifying  : 2:vim-filesystem-9.0.1592-1.amzn2.0.1.noarch               9/125
#   Verifying  : nvidia-container-toolkit-1.13.2-1.x86_64                  10/125
#   Verifying  : kernel-headers-5.10.179-171.711.amzn2.x86_64              11/125
#   Verifying  : libibverbs-core-43.0-1.amzn2.0.2.x86_64                   12/125
#   Verifying  : pcre-devel-8.32-17.amzn2.0.3.x86_64                       13/125
#   Verifying  : 1:grub2-common-2.06-9.amzn2.0.3.noarch                    14/125
#   Verifying  : webrtc-audio-processing-0.3-1.amzn2.0.1.x86_64            15/125
#   Verifying  : 1:grub2-pc-2.06-9.amzn2.0.3.x86_64                        16/125
#   Verifying  : runc-1.1.7-1.amzn2.x86_64                                 17/125
#   Verifying  : openssh-clients-7.4p1-22.amzn2.0.2.x86_64                 18/125
#   Verifying  : rsync-3.1.2-11.amzn2.0.2.x86_64                           19/125
#   Verifying  : 1:grub2-2.06-9.amzn2.0.3.x86_64                           20/125
#   Verifying  : perl-Git-2.40.1-1.amzn2.0.1.noarch                        21/125
#   Verifying  : infiniband-diags-43.0-1.amzn2.0.2.x86_64                  22/125
#   Verifying  : openssh-server-7.4p1-22.amzn2.0.2.x86_64                  23/125
#   Verifying  : libcurl-8.0.1-1.amzn2.0.1.x86_64                          24/125
#   Verifying  : webkitgtk4-jsc-2.38.5-3.amzn2.0.1.x86_64                  25/125
#   Verifying  : gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64     26/125
#   Verifying  : webkitgtk4-2.38.5-3.amzn2.0.1.x86_64                      27/125
#   Verifying  : 1:grub2-tools-efi-2.06-9.amzn2.0.3.x86_64                 28/125
#   Verifying  : 2:vim-minimal-9.0.1592-1.amzn2.0.1.x86_64                 29/125
#   Verifying  : kpatch-runtime-0.9.4-8.amzn2.noarch                       30/125
#   Verifying  : git-core-doc-2.40.1-1.amzn2.0.1.noarch                    31/125
#   Verifying  : libnvidia-container-tools-1.13.2-1.x86_64                 32/125
#   Verifying  : rdma-core-devel-43.0-1.amzn2.0.2.x86_64                   33/125
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.7.x86_64                34/125
#   Verifying  : libcurl-devel-8.0.1-1.amzn2.0.1.x86_64                    35/125
#   Verifying  : 1:grub2-efi-x64-ec2-2.06-9.amzn2.0.3.x86_64               36/125
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.7.x86_64                      37/125
#   Verifying  : 2:xxd-9.0.1592-1.amzn2.0.1.x86_64                         38/125
#   Verifying  : fuse-overlayfs-0.7.2-6.el7_8.x86_64                       39/125
#   Verifying  : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.5.x86_64        40/125
#   Verifying  : 2:vim-data-9.0.1592-1.amzn2.0.1.noarch                    41/125
#   Verifying  : libibverbs-utils-43.0-1.amzn2.0.2.x86_64                  42/125
#   Verifying  : libnvidia-container1-1.13.2-1.x86_64                      43/125
#   Verifying  : libfastjson-0.99.4-3.amzn2.0.1.x86_64                     44/125
#   Verifying  : librdmacm-43.0-1.amzn2.0.2.x86_64                         45/125
#   Verifying  : 2:vim-common-9.0.1592-1.amzn2.0.1.x86_64                  46/125
#   Verifying  : pcre-8.32-17.amzn2.0.3.x86_64                             47/125
#   Verifying  : libgudev1-219-78.amzn2.0.22.x86_64                        48/125
#   Verifying  : gstreamer1-plugins-base-1.18.4-5.amzn2.0.1.x86_64         49/125
#   Verifying  : 2:vim-enhanced-9.0.1592-1.amzn2.0.1.x86_64                50/125
#   Verifying  : graphene-1.10.6-2.amzn2.0.2.x86_64                        51/125
#   Verifying  : rdma-core-43.0-1.amzn2.0.2.x86_64                         52/125
#   Verifying  : librdmacm-utils-43.0-1.amzn2.0.2.x86_64                   53/125
#   Verifying  : gstreamer1-1.18.4-4.amzn2.0.1.x86_64                      54/125
#   Verifying  : 1:grub2-tools-extra-2.06-9.amzn2.0.3.x86_64               55/125
#   Verifying  : 1:grub2-pc-modules-2.06-9.amzn2.0.3.noarch                56/125
#   Verifying  : 1:openssl-libs-1.0.2k-24.amzn2.0.7.x86_64                 57/125
#   Verifying  : iso-codes-4.6.0-3.amzn2.noarch                            58/125
#   Verifying  : ibacm-43.0-1.amzn2.0.2.x86_64                             59/125
#   Verifying  : 1:grub2-tools-minimal-2.06-9.amzn2.0.3.x86_64             60/125
#   Verifying  : kernel-devel-5.10.179-171.711.amzn2.x86_64                61/125
#   Verifying  : dnsmasq-2.76-16.amzn2.1.4.x86_64                          62/125
#   Verifying  : openssh-7.4p1-22.amzn2.0.2.x86_64                         63/125
#   Verifying  : libibverbs-43.0-1.amzn2.0.2.x86_64                        64/125
#   Verifying  : cloud-init-19.3-46.amzn2.0.1.noarch                       65/125
#   Verifying  : sysstat-10.1.5-18.amzn2.0.3.x86_64                        66/125
#   Verifying  : 1:grub2-pc-2.06-9.amzn2.0.1.x86_64                        67/125
#   Verifying  : openssh-7.4p1-22.amzn2.0.1.x86_64                         68/125
#   Verifying  : ibacm-41.0-2.amzn2.0.2.x86_64                             69/125
#   Verifying  : perl-Git-2.39.2-1.amzn2.0.1.noarch                        70/125
#   Verifying  : 1:grub2-pc-modules-2.06-9.amzn2.0.1.noarch                71/125
#   Verifying  : 1:grub2-2.06-9.amzn2.0.1.x86_64                           72/125
#   Verifying  : sysstat-10.1.5-18.amzn2.0.2.x86_64                        73/125
#   Verifying  : webkitgtk4-jsc-2.28.2-3.amzn2.0.2.x86_64                  74/125
#   Verifying  : 2:vim-filesystem-9.0.1403-1.amzn2.0.2.noarch              75/125
#   Verifying  : openssh-clients-7.4p1-22.amzn2.0.1.x86_64                 76/125
#   Verifying  : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.1.x86_64        77/125
#   Verifying  : git-core-doc-2.39.2-1.amzn2.0.1.noarch                    78/125
#   Verifying  : 2:vim-minimal-9.0.1403-1.amzn2.0.2.x86_64                 79/125
#   Verifying  : git-core-2.39.2-1.amzn2.0.1.x86_64                        80/125
#   Verifying  : pcre-8.32-17.amzn2.0.2.x86_64                             81/125
#   Verifying  : hibagent-1.1.0-5.amzn2.noarch                             82/125
#   Verifying  : nvidia-container-toolkit-base-1.13.1-1.x86_64             83/125
#   Verifying  : 1:grub2-tools-2.06-9.amzn2.0.1.x86_64                     84/125
#   Verifying  : pcre-devel-8.32-17.amzn2.0.2.x86_64                       85/125
#   Verifying  : libibverbs-41.0-2.amzn2.0.2.x86_64                        86/125
#   Verifying  : 1:grub2-tools-minimal-2.06-9.amzn2.0.1.x86_64             87/125
#   Verifying  : gstreamer1-1.10.4-2.amzn2.0.2.x86_64                      88/125
#   Verifying  : cloud-init-19.3-46.amzn2.noarch                           89/125
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.6.x86_64                90/125
#   Verifying  : 1:grub2-common-2.06-9.amzn2.0.1.noarch                    91/125
#   Verifying  : iso-codes-3.46-2.amzn2.noarch                             92/125
#   Verifying  : libibumad-41.0-2.amzn2.0.2.x86_64                         93/125
#   Verifying  : webkitgtk4-2.28.2-3.amzn2.0.2.x86_64                      94/125
#   Verifying  : nvidia-container-toolkit-1.13.1-1.x86_64                  95/125
#   Verifying  : rdma-core-devel-41.0-2.amzn2.0.2.x86_64                   96/125
#   Verifying  : rdma-core-41.0-2.amzn2.0.2.x86_64                         97/125
#   Verifying  : kpatch-runtime-0.9.4-7.amzn2.noarch                       98/125
#   Verifying  : kernel-devel-5.10.109-104.500.amzn2.x86_64                99/125
#   Verifying  : librdmacm-utils-41.0-2.amzn2.0.2.x86_64                  100/125
#   Verifying  : libnvidia-container1-1.13.1-1.x86_64                     101/125
#   Verifying  : 2:vim-data-9.0.1403-1.amzn2.0.2.noarch                   102/125
#   Verifying  : libcurl-devel-7.88.1-1.amzn2.0.1.x86_64                  103/125
#   Verifying  : 1:openssl-libs-1.0.2k-24.amzn2.0.6.x86_64                104/125
#   Verifying  : libcurl-7.88.1-1.amzn2.0.1.x86_64                        105/125
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.6.x86_64                     106/125
#   Verifying  : librdmacm-41.0-2.amzn2.0.2.x86_64                        107/125
#   Verifying  : fuse-overlayfs-0.7.2-6.amzn2int.x86_64                   108/125
#   Verifying  : libibverbs-utils-41.0-2.amzn2.0.2.x86_64                 109/125
#   Verifying  : rsync-3.1.2-11.amzn2.0.1.x86_64                          110/125
#   Verifying  : git-2.39.2-1.amzn2.0.1.x86_64                            111/125
#   Verifying  : runc-1.1.5-1.amzn2.x86_64                                112/125
#   Verifying  : kernel-headers-5.10.179-168.710.amzn2.x86_64             113/125
#   Verifying  : libnvidia-container-tools-1.13.1-1.x86_64                114/125
#   Verifying  : openssh-server-7.4p1-22.amzn2.0.1.x86_64                 115/125
#   Verifying  : dnsmasq-2.76-16.amzn2.1.3.x86_64                         116/125
#   Verifying  : 1:grub2-efi-x64-ec2-2.06-9.amzn2.0.1.x86_64              117/125
#   Verifying  : curl-7.88.1-1.amzn2.0.1.x86_64                           118/125
#   Verifying  : gstreamer1-plugins-base-1.10.4-2.amzn2.0.3.x86_64        119/125
#   Verifying  : 2:vim-common-9.0.1403-1.amzn2.0.2.x86_64                 120/125
#   Verifying  : infiniband-diags-41.0-2.amzn2.0.2.x86_64                 121/125
#   Verifying  : libibverbs-core-41.0-2.amzn2.0.2.x86_64                  122/125
#   Verifying  : 2:vim-enhanced-9.0.1403-1.amzn2.0.2.x86_64               123/125
#   Verifying  : libfastjson-0.99.4-3.amzn2.x86_64                        124/125
#   Verifying  : gstreamer1-plugins-bad-free-1.10.4-3.amzn2.x86_64        125/125
#
# Removed:
#   kernel-devel.x86_64 0:5.10.109-104.500.amzn2
#
# Installed:
#   grub2.x86_64 1:2.06-9.amzn2.0.3
#   grub2-pc.x86_64 1:2.06-9.amzn2.0.3
#   grub2-tools.x86_64 1:2.06-9.amzn2.0.3
#   grub2-tools-efi.x86_64 1:2.06-9.amzn2.0.3
#   grub2-tools-extra.x86_64 1:2.06-9.amzn2.0.3
#   grub2-tools-minimal.x86_64 1:2.06-9.amzn2.0.3
#   kernel-devel.x86_64 0:5.10.179-171.711.amzn2
#
# Dependency Installed:
#   graphene.x86_64 0:1.10.6-2.amzn2.0.2
#   libgudev1.x86_64 0:219-78.amzn2.0.22
#   libwebp12.x86_64 0:1.2.0-3.amzn2.0.1
#   webrtc-audio-processing.x86_64 0:0.3-1.amzn2.0.1
#   xxd.x86_64 2:9.0.1592-1.amzn2.0.1
#
# Updated:
#   cloud-init.noarch 0:19.3-46.amzn2.0.1
#   curl.x86_64 0:8.0.1-1.amzn2.0.1
#   dnsmasq.x86_64 0:2.76-16.amzn2.1.4
#   fuse-overlayfs.x86_64 0:0.7.2-6.el7_8
#   git.x86_64 0:2.40.1-1.amzn2.0.1
#   git-core.x86_64 0:2.40.1-1.amzn2.0.1
#   git-core-doc.noarch 0:2.40.1-1.amzn2.0.1
#   grub2-common.noarch 1:2.06-9.amzn2.0.3
#   grub2-efi-x64-ec2.x86_64 1:2.06-9.amzn2.0.3
#   grub2-pc-modules.noarch 1:2.06-9.amzn2.0.3
#   gstreamer1.x86_64 0:1.18.4-4.amzn2.0.1
#   gstreamer1-plugins-bad-free.x86_64 0:1.18.4-5.amzn2.0.1
#   gstreamer1-plugins-base.x86_64 0:1.18.4-5.amzn2.0.1
#   hibagent.noarch 0:1.1.0-6.amzn2
#   ibacm.x86_64 0:43.0-1.amzn2.0.2
#   infiniband-diags.x86_64 0:43.0-1.amzn2.0.2
#   iso-codes.noarch 0:4.6.0-3.amzn2
#   kernel-headers.x86_64 0:5.10.179-171.711.amzn2
#   kpatch-runtime.noarch 0:0.9.4-8.amzn2
#   libcurl.x86_64 0:8.0.1-1.amzn2.0.1
#   libcurl-devel.x86_64 0:8.0.1-1.amzn2.0.1
#   libfastjson.x86_64 0:0.99.4-3.amzn2.0.1
#   libibumad.x86_64 0:43.0-1.amzn2.0.2
#   libibverbs.x86_64 0:43.0-1.amzn2.0.2
#   libibverbs-core.x86_64 0:43.0-1.amzn2.0.2
#   libibverbs-utils.x86_64 0:43.0-1.amzn2.0.2
#   libnvidia-container-tools.x86_64 0:1.13.2-1
#   libnvidia-container1.x86_64 0:1.13.2-1
#   librdmacm.x86_64 0:43.0-1.amzn2.0.2
#   librdmacm-utils.x86_64 0:43.0-1.amzn2.0.2
#   nvidia-container-toolkit.x86_64 0:1.13.2-1
#   nvidia-container-toolkit-base.x86_64 0:1.13.2-1
#   openssh.x86_64 0:7.4p1-22.amzn2.0.2
#   openssh-clients.x86_64 0:7.4p1-22.amzn2.0.2
#   openssh-server.x86_64 0:7.4p1-22.amzn2.0.2
#   openssl.x86_64 1:1.0.2k-24.amzn2.0.7
#   openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.7
#   openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.7
#   pcre.x86_64 0:8.32-17.amzn2.0.3
#   pcre-devel.x86_64 0:8.32-17.amzn2.0.3
#   perl-Git.noarch 0:2.40.1-1.amzn2.0.1
#   python-pillow.x86_64 0:2.0.0-23.gitd1c6db8.amzn2.0.5
#   rdma-core.x86_64 0:43.0-1.amzn2.0.2
#   rdma-core-devel.x86_64 0:43.0-1.amzn2.0.2
#   rsync.x86_64 0:3.1.2-11.amzn2.0.2
#   runc.x86_64 0:1.1.7-1.amzn2
#   sysstat.x86_64 0:10.1.5-18.amzn2.0.3
#   vim-common.x86_64 2:9.0.1592-1.amzn2.0.1
#   vim-data.noarch 2:9.0.1592-1.amzn2.0.1
#   vim-enhanced.x86_64 2:9.0.1592-1.amzn2.0.1
#   vim-filesystem.noarch 2:9.0.1592-1.amzn2.0.1
#   vim-minimal.x86_64 2:9.0.1592-1.amzn2.0.1
#   webkitgtk4.x86_64 0:2.38.5-3.amzn2.0.1
#   webkitgtk4-jsc.x86_64 0:2.38.5-3.amzn2.0.1
#
# Replaced:
#   grub2.x86_64 1:2.06-9.amzn2.0.1     grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#
# Complete!
# Detected operating system as amzn/2.
# Checking for curl...
# Detected curl...
# Downloading repository file: https://packagecloud.io/install/repositories/github/git-lfs/config_file.repo?os=amzn&dist=2&source=script
# done.
# Installing pygpgme to verify GPG signatures...
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# github_git-lfs-source/signature                          |  819 B     00:00
# Retrieving key from https://packagecloud.io/github/git-lfs/gpgkey
# Importing GPG key 0xDC282033:
#  Userid     : "https://packagecloud.io/github/git-lfs (https://packagecloud.io/docs#gpg_signing) <support@packagecloud.io>"
#  Fingerprint: 6d39 8dbd 30dd 7894 1e2c 4797 fe2a 5f8b dc28 2033
#  From       : https://packagecloud.io/github/git-lfs/gpgkey
# github_git-lfs-source/signature                          |  951 B     00:00 !!!
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# github_git-lfs-source/primary                              |  175 B   00:00
# 61 packages excluded due to repository priority protections
# Package pygpgme-0.3-9.amzn2.0.3.x86_64 already installed and latest version
# Nothing to do
# Installing yum-utils...
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 61 packages excluded due to repository priority protections
# Package yum-utils-1.1.31-46.amzn2.0.1.noarch already installed and latest version
# Nothing to do
# Generating yum cache for github_git-lfs...
# Importing GPG key 0xDC282033:
#  Userid     : "https://packagecloud.io/github/git-lfs (https://packagecloud.io/docs#gpg_signing) <support@packagecloud.io>"
#  Fingerprint: 6d39 8dbd 30dd 7894 1e2c 4797 fe2a 5f8b dc28 2033
#  From       : https://packagecloud.io/github/git-lfs/gpgkey
# Generating yum cache for github_git-lfs-source...
#
# The repository is setup! You can now install packages.
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 61 packages excluded due to repository priority protections
# No package git-lfs available.
# Package git-2.40.1-1.amzn2.0.1.x86_64 already installed and latest version
# Nothing to do
# Detected operating system as amzn/2.
# Checking for curl...
# Detected curl...
# Downloading repository file: https://packagecloud.io/install/repositories/github/git-lfs/config_file.repo?os=amzn&dist=2&source=script
# done.
# Installing pygpgme to verify GPG signatures...
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# github_git-lfs-source/signature                          |  819 B     00:00
# github_git-lfs-source/signature                          |  951 B     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# 61 packages excluded due to repository priority protections
# Package pygpgme-0.3-9.amzn2.0.3.x86_64 already installed and latest version
# Nothing to do
# Installing yum-utils...
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 61 packages excluded due to repository priority protections
# Package yum-utils-1.1.31-46.amzn2.0.1.noarch already installed and latest version
# Nothing to do
# Generating yum cache for github_git-lfs...
# Generating yum cache for github_git-lfs-source...
#
# The repository is setup! You can now install packages.
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# adding repo from: https://packagecloud.io/github/git-lfs/el/7/x86_64
#
# [packagecloud.io_github_git-lfs_el_7_x86_64]
# name=added from: https://packagecloud.io/github/git-lfs/el/7/x86_64
# baseurl=https://packagecloud.io/github/git-lfs/el/7/x86_64
# enabled=1
#
#
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# packagecloud.io_github_git-lfs_el_7_x86_64               | 1.8 kB     00:00
# packagecloud.io_github_git-lfs_el_7_x86_64/primary         | 5.0 kB   00:00
# packagecloud.io_github_git-lfs_el_7_x86_64                                45/45
# 61 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package git-lfs.x86_64 0:3.3.0-1.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package Arch   Version        Repository                                  Size
# ================================================================================
# Installing:
#  git-lfs x86_64 3.3.0-1.el7    packagecloud.io_github_git-lfs_el_7_x86_64 3.6 M
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 3.6 M
# Installed size: 11 M
# Downloading packages:
# git-lfs-3.3.0-1.el7.x86_64.rpm                             | 3.6 MB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : git-lfs-3.3.0-1.el7.x86_64                                   1/1
# Git LFS initialized.
#   Verifying  : git-lfs-3.3.0-1.el7.x86_64                                   1/1
#
# Installed:
#   git-lfs.x86_64 0:3.3.0-1.el7
#
# Complete!

# %%
import sagemaker
import boto3
sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker role arn: arn:aws:iam::390771086433:role/service-role/AmazonSageMaker-ExecutionRole-20230605T175839
# sagemaker bucket: sagemaker-us-east-1-390771086433
# sagemaker session region: us-east-1

# %%
# !mkdir code

# %%
# %%writefile code/inference.py

import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import torch

def model_fn(model_dir):
    # Load model from HuggingFace Hub
    processor = BlipProcessor.from_pretrained(model_dir)
    model = BlipForConditionalGeneration.from_pretrained(model_dir)
    
    return model, processor

def predict_fn(data, model_and_processor):
    # Destruct model and tokenizer
    model, processor = model_and_processor
    
    # Check if 'inputs' key exists in the dictionary
    if 'inputs' in data:
        inputs = data['inputs']
        # Extract 'img_url' and 'text'
        img_url = inputs.get('img_url')
        text = inputs.get('text')
        max_new_tokens = inputs.get('max_new_tokens', 20)
        skip_special_tokens = inputs.get('skip_special_tokens', True) 
        # Raise error if 'img_url' is missing
        if img_url is None:
            raise ValueError("Dictionary is missing 'img_url' key. It should be formatted as {'inputs' : {'img_url' : '<URL>', 'text': '<Text>' }}")
    else:
        raise ValueError("Dictionary is missing 'inputs' key. It should be formatted as {'inputs' : {'img_url' : '<URL>', 'text': '<Text>' }}")
    
    # Load the image
    raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')

    # Conditional image captioning
    if text:
        inputs = processor(raw_image, text, return_tensors="pt")
        out = model.generate(**inputs, max_new_tokens=max_new_tokens)
        caption = {'generated text' : processor.decode(out[0], skip_special_tokens=skip_special_tokens)}
    else:
        # Unconditional image captioning
        inputs = processor(raw_image, return_tensors="pt")
        out = model.generate(**inputs, max_new_tokens=max_new_tokens)
        caption = {'generated text' : processor.decode(out[0], skip_special_tokens=skip_special_tokens)}
        
    return caption
# Out:
# Writing code/inference.py

# %%
repository = "Salesforce/blip-image-captioning-base"
model_id=repository.split("/")[-1]
s3_location=f"s3://{sess.default_bucket()}/custom_inference/{model_id}/model.tar.gz"

# %%
# !git lfs install
# !git clone https://huggingface.co/$repository
# Out:
# Git LFS initialized.
# Cloning into 'blip-image-captioning-base'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 70 (delta 6), reused 15 (delta 5), pack-reused 52
# Unpacking objects: 100% (70/70), 324.78 KiB | 7.92 MiB/s, done.
# Filtering content: 100% (2/2), 1.84 GiB | 54.79 MiB/s, done.

# %%
# !cp -r code/ $model_id/code/

# %%
# %cd $model_id
# !tar zcvf model.tar.gz *
# Out:
# /home/ec2-user/SageMaker/blip-image-captioning-base
# code/
# code/inference.py
# config.json
# preprocessor_config.json
# pytorch_model.bin
# README.md
# special_tokens_map.json
# tf_model.h5
# tokenizer_config.json
# tokenizer.json
# vocab.txt

# %%
# !aws s3 cp model.tar.gz $s3_location
# Out:
# upload: ./model.tar.gz to s3://sagemaker-us-east-1-390771086433/custom_inference/blip-image-captioning-base/model.tar.gz

# %%
from sagemaker.huggingface.model import HuggingFaceModel


# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   model_data=s3_location,       # path to your model and script
   role=role,                    # iam role with permissions to create an Endpoint
   transformers_version="4.26",  # transformers version used
   pytorch_version="1.13",        # pytorch version used
   py_version='py39',            # python version used
)

# deploy the endpoint endpoint
predictor = huggingface_model.deploy(
    initial_instance_count=1,
    instance_type="ml.g4dn.xlarge"
    )
# Out:
# --------!

# %%
data = {
    "inputs": {
        "img_url": "https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885_960_720.jpg",
        "text" : "An image of ",
    }
}

res = predictor.predict(data=data)
print(res)
# Out:
# {'generated text': 'an image of a tree in the middle of'}

# %%
import boto3
import json

# Create a SageMaker runtime client
client = boto3.client('sagemaker-runtime')

# Specify the SageMaker endpoint name
endpoint_name = "huggingface-pytorch-inference-2023-06-19-19-51-40-819"

# Provide the payload you want to use for prediction
data = {
    "inputs": {
        "img_url": "https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885_960_720.jpg",
        "text" : "An image of ",
    }
}
payload = json.dumps(data)

# Specify the content type and accept headers
content_type = "application/json"
accept = "application/json"

# Invoke the endpoint
response = client.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType=content_type,
    Accept=accept,
    Body=payload
)

# Print the prediction result
print(response['Body'].read().decode())
# Out:
# {"generated text":"an image of a tree in the middle of a lake"}
